# %%
# !pip install mlxtend

# %%
import pandas as pd

# %% [markdown]
# ### Create the dataset

# %%
dataset = [
    ['Apple','Beer','Rice','Chicken'],
    ['Apple','Beer','Rice'],
    ['Apple','Beer'],
    ['Apple','Pear'],
    ['Milk','Beer','Rice','Chicken'],
    ['Milk','Beer','Rice'],
    ['Milk','Beer'],
    ['Milk','Pear'],
]

# %%
x = [
    ['🍎','🍺','🍚','🍗'],
    ['🍎','🍺','🍚'],
    ['🍎','🍺'],
    ['🍎','🍐'],
    ['🥛','🍺','🍚','🍗'],
    ['🥛','🍺','🍚'],
    ['🥛','🍺'],
    ['🥛','🍐'],
]

# %%
x
# Out:
# [['🍎', '🍺', '🍚', '🍗'],
#  ['🍎', '🍺', '🍚'],
#  ['🍎', '🍺'],
#  ['🍎', '🍐'],
#  ['🥛', '🍺', '🍚', '🍗'],
#  ['🥛', '🍺', '🍚'],
#  ['🥛', '🍺'],
#  ['🥛', '🍐']]

# %%
dataset
# Out:
# [['Apple', 'Beer', 'Rice', 'Chicken'],
#  ['Apple', 'Beer', 'Rice'],
#  ['Apple', 'Beer'],
#  ['Apple', 'Pear'],
#  ['Milk', 'Beer', 'Rice', 'Chicken'],
#  ['Milk', 'Beer', 'Rice'],
#  ['Milk', 'Beer'],
#  ['Milk', 'Pear']]

# %% [markdown]
# ### Transaction encoder for creating structured data

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()

# %%
df_enc = te.fit_transform(dataset)

# %%
df_enc
# Out:
# array([[ True,  True,  True, False, False,  True],
#        [ True,  True, False, False, False,  True],
#        [ True,  True, False, False, False, False],
#        [ True, False, False, False,  True, False],
#        [False,  True,  True,  True, False,  True],
#        [False,  True, False,  True, False,  True],
#        [False,  True, False,  True, False, False],
#        [False, False, False,  True,  True, False]])

# %%
te.columns_
# Out:
# ['Apple', 'Beer', 'Chicken', 'Milk', 'Pear', 'Rice']

# %%
df = pd.DataFrame(df_enc, columns=te.columns_)

# %%
df
# Out:
#    Apple   Beer  Chicken   Milk   Pear   Rice
# 0   True   True     True  False  False   True
# 1   True   True    False  False  False   True
# 2   True   True    False  False  False  False
# 3   True  False    False  False   True  False
# 4  False   True     True   True  False   True
# 5  False   True    False   True  False   True
# 6  False   True    False   True  False  False
# 7  False  False    False   True   True  False

# %% [markdown]
# ### Step-1 Generate the frequent itemsets

# %%
from mlxtend.frequent_patterns import apriori

# %%
freq_itemsets = apriori(df, min_support=0.25, use_colnames=True)

# %%
freq_itemsets
# Out:
#     support               itemsets
# 0     0.500                (Apple)
# 1     0.750                 (Beer)
# 2     0.250              (Chicken)
# 3     0.500                 (Milk)
# 4     0.250                 (Pear)
# 5     0.500                 (Rice)
# 6     0.375          (Apple, Beer)
# 7     0.250          (Rice, Apple)
# 8     0.250        (Chicken, Beer)
# 9     0.375           (Milk, Beer)
# 10    0.500           (Rice, Beer)
# 11    0.250        (Rice, Chicken)
# 12    0.250           (Rice, Milk)
# 13    0.250    (Rice, Apple, Beer)
# 14    0.250  (Rice, Chicken, Beer)
# 15    0.250     (Rice, Milk, Beer)

# %% [markdown]
# ### Step-2 Generate the association rules

# %%
from mlxtend.frequent_patterns import association_rules

# %%
rules = association_rules(freq_itemsets, metric='confidence',
                         min_threshold=0.50)

# %%
rules
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0           (Apple)           (Beer)               0.500               0.750
# 1            (Beer)          (Apple)               0.750               0.500
# 2            (Rice)          (Apple)               0.500               0.500
# 3           (Apple)           (Rice)               0.500               0.500
# 4         (Chicken)           (Beer)               0.250               0.750
# 5            (Milk)           (Beer)               0.500               0.750
# 6            (Beer)           (Milk)               0.750               0.500
# 7            (Rice)           (Beer)               0.500               0.750
# 8            (Beer)           (Rice)               0.750               0.500
# 9            (Rice)        (Chicken)               0.500               0.250
# 10        (Chicken)           (Rice)               0.250               0.500
# 11           (Rice)           (Milk)               0.500               0.500
# 12           (Milk)           (Rice)               0.500               0.500
# 13    (Rice, Apple)           (Beer)               0.250               0.750
# 14     (Rice, Beer)          (Apple)               0.500               0.500
# 15    (Apple, Beer)           (Rice)               0.375               0.500
# 16           (Rice)    (Apple, Beer)               0.500               0.375
# 17          (Apple)     (Rice, Beer)               0.500               0.500
# 18  (Rice, Chicken)           (Beer)               0.250               0.750
# 19     (Rice, Beer)        (Chicken)               0.500               0.250
# 20  (Chicken, Beer)           (Rice)               0.250               0.500
# 21           (Rice)  (Chicken, Beer)               0.500               0.250
# 22        (Chicken)     (Rice, Beer)               0.250               0.500
# 23     (Rice, Milk)           (Beer)               0.250               0.750
# 24     (Rice, Beer)           (Milk)               0.500               0.500
# 25     (Milk, Beer)           (Rice)               0.375               0.500
# 26           (Rice)     (Milk, Beer)               0.500               0.375
# 27           (Milk)     (Rice, Beer)               0.500               0.500
#
#     support  confidence      lift  leverage  conviction
# 0     0.375    0.750000  1.000000    0.0000        1.00
# 1     0.375    0.500000  1.000000    0.0000        1.00
# 2     0.250    0.500000  1.000000    0.0000        1.00
# 3     0.250    0.500000  1.000000    0.0000        1.00
# 4     0.250    1.000000  1.333333    0.0625         inf
# 5     0.375    0.750000  1.000000    0.0000        1.00
# 6     0.375    0.500000  1.000000    0.0000        1.00
# 7     0.500    1.000000  1.333333    0.1250         inf
# 8     0.500    0.666667  1.333333    0.1250        1.50
# 9     0.250    0.500000  2.000000    0.1250        1.50
# 10    0.250    1.000000  2.000000    0.1250         inf
# 11    0.250    0.500000  1.000000    0.0000        1.00
# 12    0.250    0.500000  1.000000    0.0000        1.00
# 13    0.250    1.000000  1.333333    0.0625         inf
# 14    0.250    0.500000  1.000000    0.0000        1.00
# 15    0.250    0.666667  1.333333    0.0625        1.50
# 16    0.250    0.500000  1.333333    0.0625        1.25
# 17    0.250    0.500000  1.000000    0.0000        1.00
# 18    0.250    1.000000  1.333333    0.0625         inf
# 19    0.250    0.500000  2.000000    0.1250        1.50
# 20    0.250    1.000000  2.000000    0.1250         inf
# 21    0.250    0.500000  2.000000    0.1250        1.50
# 22    0.250    1.000000  2.000000    0.1250         inf
# 23    0.250    1.000000  1.333333    0.0625         inf
# 24    0.250    0.500000  1.000000    0.0000        1.00
# 25    0.250    0.666667  1.333333    0.0625        1.50
# 26    0.250    0.500000  1.333333    0.0625        1.25
# 27    0.250    0.500000  1.000000    0.0000        1.00

# %% [markdown]
# ### Extract specific columns

# %%
rules = rules[['antecedents','consequents','support','confidence']]

# %%
rules
# Out:
#         antecedents      consequents  support  confidence
# 0           (Apple)           (Beer)    0.375    0.750000
# 1            (Beer)          (Apple)    0.375    0.500000
# 2            (Rice)          (Apple)    0.250    0.500000
# 3           (Apple)           (Rice)    0.250    0.500000
# 4         (Chicken)           (Beer)    0.250    1.000000
# 5            (Milk)           (Beer)    0.375    0.750000
# 6            (Beer)           (Milk)    0.375    0.500000
# 7            (Rice)           (Beer)    0.500    1.000000
# 8            (Beer)           (Rice)    0.500    0.666667
# 9            (Rice)        (Chicken)    0.250    0.500000
# 10        (Chicken)           (Rice)    0.250    1.000000
# 11           (Rice)           (Milk)    0.250    0.500000
# 12           (Milk)           (Rice)    0.250    0.500000
# 13    (Rice, Apple)           (Beer)    0.250    1.000000
# 14     (Rice, Beer)          (Apple)    0.250    0.500000
# 15    (Apple, Beer)           (Rice)    0.250    0.666667
# 16           (Rice)    (Apple, Beer)    0.250    0.500000
# 17          (Apple)     (Rice, Beer)    0.250    0.500000
# 18  (Rice, Chicken)           (Beer)    0.250    1.000000
# 19     (Rice, Beer)        (Chicken)    0.250    0.500000
# 20  (Chicken, Beer)           (Rice)    0.250    1.000000
# 21           (Rice)  (Chicken, Beer)    0.250    0.500000
# 22        (Chicken)     (Rice, Beer)    0.250    1.000000
# 23     (Rice, Milk)           (Beer)    0.250    1.000000
# 24     (Rice, Beer)           (Milk)    0.250    0.500000
# 25     (Milk, Beer)           (Rice)    0.250    0.666667
# 26           (Rice)     (Milk, Beer)    0.250    0.500000
# 27           (Milk)     (Rice, Beer)    0.250    0.500000

# %% [markdown]
# ### Extract using condition

# %%
rules[rules['confidence'] > 0.5]
# Out:
#         antecedents   consequents  support  confidence
# 0           (Apple)        (Beer)    0.375    0.750000
# 4         (Chicken)        (Beer)    0.250    1.000000
# 5            (Milk)        (Beer)    0.375    0.750000
# 7            (Rice)        (Beer)    0.500    1.000000
# 8            (Beer)        (Rice)    0.500    0.666667
# 10        (Chicken)        (Rice)    0.250    1.000000
# 13    (Rice, Apple)        (Beer)    0.250    1.000000
# 15    (Apple, Beer)        (Rice)    0.250    0.666667
# 18  (Rice, Chicken)        (Beer)    0.250    1.000000
# 20  (Chicken, Beer)        (Rice)    0.250    1.000000
# 22        (Chicken)  (Rice, Beer)    0.250    1.000000
# 23     (Rice, Milk)        (Beer)    0.250    1.000000
# 25     (Milk, Beer)        (Rice)    0.250    0.666667

# %%
rules[(rules['confidence'] > 0.5) & (rules['support'] > 0.25)]
# Out:
#   antecedents consequents  support  confidence
# 0     (Apple)      (Beer)    0.375    0.750000
# 5      (Milk)      (Beer)    0.375    0.750000
# 7      (Rice)      (Beer)    0.500    1.000000
# 8      (Beer)      (Rice)    0.500    0.666667

# %% [markdown]
# ### Recommendation

# %%
rules[rules['antecedents'] == {'Rice'}]
# Out:
#    antecedents      consequents  support  confidence
# 2       (Rice)          (Apple)     0.25         0.5
# 7       (Rice)           (Beer)     0.50         1.0
# 9       (Rice)        (Chicken)     0.25         0.5
# 11      (Rice)           (Milk)     0.25         0.5
# 16      (Rice)    (Apple, Beer)     0.25         0.5
# 21      (Rice)  (Chicken, Beer)     0.25         0.5
# 26      (Rice)     (Milk, Beer)     0.25         0.5

# %%
rules[(rules['antecedents'] == {'Rice'}) & (rules['confidence']>0.5)]
# Out:
#   antecedents consequents  support  confidence
# 7      (Rice)      (Beer)      0.5         1.0

# %%
rules[(rules['antecedents'] == {'Rice'}) 
      & (rules['confidence']>0.5)]['consequents']
# Out:
# 7    (Beer)
# Name: consequents, dtype: object

# %%
rules[rules['antecedents'] == {'Milk','Beer'}]['consequents']
# Out:
# 25    (Rice)
# Name: consequents, dtype: object

# %% [markdown]
# ### Sort the rules

# %%
rules.sort_values(by='confidence', ascending=False)
# Out:
#         antecedents      consequents  support  confidence
# 22        (Chicken)     (Rice, Beer)    0.250    1.000000
# 20  (Chicken, Beer)           (Rice)    0.250    1.000000
# 4         (Chicken)           (Beer)    0.250    1.000000
# 13    (Rice, Apple)           (Beer)    0.250    1.000000
# 7            (Rice)           (Beer)    0.500    1.000000
# 18  (Rice, Chicken)           (Beer)    0.250    1.000000
# 23     (Rice, Milk)           (Beer)    0.250    1.000000
# 10        (Chicken)           (Rice)    0.250    1.000000
# 0           (Apple)           (Beer)    0.375    0.750000
# 5            (Milk)           (Beer)    0.375    0.750000
# 15    (Apple, Beer)           (Rice)    0.250    0.666667
# 8            (Beer)           (Rice)    0.500    0.666667
# 25     (Milk, Beer)           (Rice)    0.250    0.666667
# 21           (Rice)  (Chicken, Beer)    0.250    0.500000
# 24     (Rice, Beer)           (Milk)    0.250    0.500000
# 26           (Rice)     (Milk, Beer)    0.250    0.500000
# 19     (Rice, Beer)        (Chicken)    0.250    0.500000
# 14     (Rice, Beer)          (Apple)    0.250    0.500000
# 17          (Apple)     (Rice, Beer)    0.250    0.500000
# 16           (Rice)    (Apple, Beer)    0.250    0.500000
# 1            (Beer)          (Apple)    0.375    0.500000
# 12           (Milk)           (Rice)    0.250    0.500000
# 11           (Rice)           (Milk)    0.250    0.500000
# 9            (Rice)        (Chicken)    0.250    0.500000
# 6            (Beer)           (Milk)    0.375    0.500000
# 3           (Apple)           (Rice)    0.250    0.500000
# 2            (Rice)          (Apple)    0.250    0.500000
# 27           (Milk)     (Rice, Beer)    0.250    0.500000

# %% [markdown]
# ### Save the rules

# %%
rules.to_csv('rules.csv', index=False)
